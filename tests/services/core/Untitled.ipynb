# %%
import pandas as pd
import numpy as np

import pyarrow.parquet as pq

# %%
flightspq = pq.read_table("flights.parquet")
flights = flightspq.to_pandas()
flights.sort(['Price'])
#flights.shape
# Out:
#    Airline      ArrivalTimeUTC       DepartTimeUTC Duration  FlightNum  \
# 0       AA 2019-04-30 06:10:00 2019-04-29 23:00:00   7h 10m       6139
# 1       AA 2019-04-29 09:50:00 2019-04-29 02:30:00   7h 20m        104
# 2       DL 2019-04-30 09:15:00 2019-04-30 02:00:00   7h 15m       4377
# 3       KL 2019-05-01 09:15:00 2019-05-01 02:00:00   7h 15m       4828
# 4       AY 2019-04-30 10:05:00 2019-04-30 03:00:00    7h 5m       5482
# 5       AY 2019-04-30 18:45:00 2019-04-30 11:55:00   6h 50m       5478
# 6       VS 2019-04-29 19:10:00 2019-04-29 12:15:00   6h 55m         26
# 7       DL 2019-04-30 19:10:00 2019-04-30 12:15:00   6h 55m       4371
# 8       AY 2019-04-30 21:10:00 2019-04-30 14:15:00   6h 55m       4036
# 9       AY 2019-05-01 10:05:00 2019-05-01 03:00:00    7h 5m       5482
# 10      AY 2019-05-01 05:20:00 2019-04-30 22:05:00   7h 15m       4012
# 11      DL 2019-05-01 08:15:00 2019-05-01 01:00:00   7h 15m       4375
# ...
