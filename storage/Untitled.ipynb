# %%
import pandas as pd
import numpy as np

import pyarrow.parquet as pq

# %%
flightspq = pq.read_table("flights.parquet")
flights = flightspq.to_pandas()
flights = flights.sort_values(['Price'])
flights
# Out:
#    Airline      ArrivalTimeUTC       DepartTimeUTC Duration  FlightNum FlyTo  \
# 0       AA 2019-04-30 06:10:00 2019-04-29 23:00:00   7h 10m       6139   LHR
# 1       AA 2019-04-29 09:50:00 2019-04-29 02:30:00   7h 20m        104   LHR
# 2       DL 2019-04-30 09:15:00 2019-04-30 02:00:00   7h 15m       4377   LHR
# 3       KL 2019-05-01 09:15:00 2019-05-01 02:00:00   7h 15m       4828   LHR
# 4       AY 2019-04-30 10:05:00 2019-04-30 03:00:00    7h 5m       5482   LHR
# 17      VS 2019-05-01 06:50:00 2019-04-30 23:30:00   7h 20m       4028   LHR
# 16      DL 2019-05-01 06:20:00 2019-04-30 23:00:00   7h 20m       4412   LHR
# 15      AY 2019-05-01 09:50:00 2019-05-01 02:30:00   7h 20m       4016   LHR
# 14      AY 2019-05-01 06:40:00 2019-04-30 23:20:00   7h 20m       4018   LHR
# 13      DL 2019-04-29 06:50:00 2019-04-28 23:30:00   7h 20m          1   LHR
# 12      DL 2019-05-01 07:45:00 2019-05-01 00:30:00   7h 15m       4359   LHR
# ...
