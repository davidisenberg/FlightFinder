# %%
import pandas as pd
import numpy as np

import pyarrow.parquet as pq

# %%
flightspq = pq.read_table("flights.parquet")
flights = flightspq.to_pandas()
flights
# Out:
# 2607

# %%
flightspq = pq.read_table("directs.parquet")
directs = flightspq.to_pandas().drop_duplicates()
directs = directs[directs["FlyFrom"] == "JFK"]
directs
# Out:
#     FlyTo FlyFrom
# 184   AUH     JFK
# 185   ACC     JFK
# 186   BQN     JFK
# 187   AMM     JFK
# 188   AMS     JFK
# 189   ATH     JFK
# 190   ATL     JFK
# 191   AUS     JFK
# 192   GYD     JFK
# 193   BWI     JFK
# 194   BCN     JFK
# 195   HYA     JFK
# 196   PEK     JFK
# 197   BEG     JFK
# 198   TXL     JFK
# 199   BOG     JFK
# 200   BOM     JFK
# 201   BOS     JFK
# 202   BGI     JFK
# 203   BRU     JFK
# 204   BUD     JFK
# 205   EZE     JFK
# 206   BUF     JFK
# 207   BUR     JFK
# 208   BTV     JFK
# 209   CAI     JFK
# 210   YYC     JFK
# 211   CUN     JFK
# 212   CCS     JFK
# 213   CTG     JFK
# ..    ...     ...
# 347   TAB     JFK
# 348   SEA     JFK
# 349   ICN     JFK
# 350   PVG     JFK
# 351   SNN     JFK
# 352   GND     JFK
# 353   ANU     JFK
# 354   STT     JFK
# 355   ARN     JFK
# 356   SYR     JFK
# 357   TPE     JFK
# 358   TPA     JFK
# 359   LDE     JFK
# 360   TAS     JFK
# 361   TLV     JFK
# 362   HND     JFK
# 363   NRT     JFK
# 364   YYZ     JFK
# ...
